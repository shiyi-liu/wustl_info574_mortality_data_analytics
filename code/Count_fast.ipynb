# %%
import numpy as np
import pandas as pd
import math
import gc

# %%
file = r'./data_compressed.csv'
df = pd.read_csv(file)

# %%
df['occurence']=1

# %%
df.groupby(['sex','current_data_year', 'month_of_death', 'age','education'], sort=True).occurence.sum().reset_index()
# Out:
#       sex  current_data_year  month_of_death  age  education  occurence
# 0       F               2005               1    1        0.0        722
# 1       F               2005               1    1        1.0        422
# 2       F               2005               1    1        3.0         56
# 3       F               2005               1    2        0.0         66
# 4       F               2005               1    2        1.0         51
# 5       F               2005               1    2        3.0         13
# 6       F               2005               1    3        0.0         58
# 7       F               2005               1    3        1.0         59
# 8       F               2005               1    3        3.0         10
# 9       F               2005               1    4        0.0         19
# 10      F               2005               1    4        1.0        239
# 11      F               2005               1    4        2.0         27
# ...
