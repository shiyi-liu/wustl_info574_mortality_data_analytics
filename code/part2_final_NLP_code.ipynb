# %%
from nltk.tokenize import word_tokenize, wordpunct_tokenize
from nltk.corpus import stopwords 
from gensim.test.utils import common_texts
from gensim.models import Word2Vec
import gensim.downloader as api
from gensim.models import TfidfModel
from gensim.corpora import Dictionary
import pandas as pd
from gensim.models import KeyedVectors
import numpy as np
import nltk
import re

# %% [markdown]
# ## README
# ### Remark:
# * as for manual comparison, in the case that multiple diseases occurs in one medical transcription, as long as one of them is recgonized correctly by the similarity matrix, it is considered as correct match. <br/> (i.e.: mt {Patient with a diagnosis of pancreatitis, developed hypotension and possible sepsis and respiratory, as well as renal failure.}; icd {Diseases of the respiratory system})
# * the .csv file "allvalid2011.csv" was modified from the original version. Please find the cooresponding file attahced with the code
# * the ICD type 21, 22 were dropped due to lack of sufficient description data.
#
# ### Version log:
# **version template: v3.1.0 **
# * 3: Vectorization method 3
# * 1: The second experimented threshold value
# * 0: The first examined shffuled dataset <br/>
#
# #### Version Desc
# * v1: normal W2V process; take average as doc rep
# * v2: lower the implication from high-frequency words (like "history") by subtracting the mean of 22 ICD vectors from each element in each ICD vector as well as each medical transcription vector ; still, take average as doc rep
# * v3: for POS-tag, also keep adj and verb
# * v4: use tf-idf weighted measure to represent a doc
#
# version|w2v|POS tag|doc rep
# -|:-|:-|:-
# v1|pretrained w2v model|nouns|mean value of word vectors
# v2|pretrained w2v model|nouns|
# v3|pretrained w2v model|nouns, verbs, adjectives|mean value of word vectors
# v4|pretrained w2v model|nouns|tf-idf weighted measure
#
#
# ---
# #### Result Log
# version|median|mean|max|threshold|# after threshold|accuracy
# -|-|-|-|-|-|-
# v1.0.0|0.2796395575950238|0.2833969991805676|0.8583709831829136|0.5|3381|40%
# v1.1.0||||0.6|1817|80%
# v1.2.0||||0.7|639|80%
# v2.0.0|-0.02174311680385281|-0.0012455847865164764|1.0|0.5|1135|70%
# v2.0.1||||||70%
# v3.0.0|0.3386405344879612|0.3407677889369111|0.8583447111956868|0.5|3814|50%
# v3.0.1||||||50%
# v3.1.0||||0.6|2294|50%
# v4.0.0|0.2073973010080073|0.22690196166648854|0.9109624806359937|0.5|2435|70%
# v4.0.1||||||60%
# v4.1.0||||0.6|1030|100%
#
#
#
#
# #### Code Version Instruction
# * To implement version 1, 2, 3, run sections 1-2-3-5-6; please pay attention to comments saying "RUN THIS CELL ONLY WHEN ..." and modify the code according to the vesion you are implementing
# * To implement version 4, run sections 1-4-5-6.

# %% [markdown]
# ## 1 Text Aggregation

# %%
icd = pd.read_csv("./data/allvalid2011.csv")

# %%
# open files storing description strings
# only execute for initializing the process

txt = []
for i in range(20):
    i+=1
    file = open("./data/icd%d.txt" %i, "a+", encoding='UTF-8')
    txt.append(file)
#     file.close()

# %%
# classify each row of icd into 22 cates according to col type

for i in range(len(icd)):
#     print(icd['type'][i])
    type = icd['type'][i] # txt_index = type-1
    txt[type-1].write(icd["ICD Title"][i])

# %%
# close files
for i in range(22):
    txt[i].close()

# %% [markdown]
# ## 2 Vectorization - ICD Descriptions

# %%
# RUN THIS CELL ONLY WHEN IMPLEMENTING VERSION 3
# to implement version 3, replace the current POS-tag filter with this list for both vectorization sections
listPos = ['NN', 'NNP', 'NNS', 'NNPS', 'JJ', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']

# %%
model = KeyedVectors.load_word2vec_format('C:\PubMed-and-PMC-w2v.bin', binary=True)

# %%
icd_vec=np.empty((0, 200), float)

for i in range(20): 
    ite_name = i+1
    file = open("./data/icd%d.txt" %ite_name, "r")
    raw_data = file.read()
    file.close()

    stop_words = set(stopwords.words('english')) 
    word_tokens = word_tokenize(raw_data)
    
    #convert all words to lower case
    word_tokens = [w.lower() for w in word_tokens] 
    #remove words in stopwords list
    word_tokens = [w.lower() for w in word_tokens if w not in stop_words] 
    #only keep alphabetic terms
    word_tokens = [w.lower() for w in word_tokens if w.isalpha()] 
    
    token_pos=nltk.pos_tag(word_tokens)

    word2vec_ls=np.empty((0, 200), float)
    for word, pos in token_pos:
        if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS'):
#         if (pos in listPos):
            try:
                word2vec_ls=np.vstack([word2vec_ls, model.word_vec(word)])
            except:
                pass

    if np.any(np.isnan(word2vec_ls)) or len(word2vec_ls)==0:
        desc_vec=np.zeros((1, 200))
    else:
        desc_vec = np.mean(word2vec_ls, axis=0).reshape(1, 200)
    icd_vec=np.vstack([icd_vec, desc_vec])

# %%
icd_vec.shape
# Out:
# (20, 200)

# %%
# RUN THIS CELL ONLY WHEN IMPLEMENTING VERSION 2

icd_vec_mean = np.mean(icd_vec, axis = 0)
icd_vec_new = np.empty((0,200),float)
for item in icd_vec:
    item = np.subtract(item, icd_vec_mean) # subtracting the mean value from document reps
    icd_vec_new = np.vstack([icd_vec_new, item])

icd_vec_new.shape
# Out:
# (22, 200)

# %%
# write icd vectors to a csv file
dfIcdV = pd.DataFrame(icd_vec)
dfIcdV.to_csv(path_or_buf = './data/IcdV_v3.csv', index=False)

# %% [markdown]
# ## 3 Vectorization - Medical Transcriptions

# %%
mt = pd.read_csv("./data/medicaltranscriptions-1.csv")

# %%
description_vec=np.empty((0, 200), float)

for i in range(len(mt["description"])):
    word2vec_ls=np.empty((0, 200), float)
    mt_token_pos=nltk.pos_tag(nltk.word_tokenize(mt["description"][i]))
    # for each word in a case, convert t into vector using model
    # take the exception into consideration (i.e.: word is not in the model)
    for word, pos in mt_token_pos:
        if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS'):
#         if (pos in listPos):
            try:
                word2vec_ls=np.vstack([word2vec_ls, model.word_vec(word)])
            except:
                pass
    # if the case is empty, convert the document vector into zeros, otherwise calculate the average value of word vectors
    if np.any(np.isnan(word2vec_ls)) or len(word2vec_ls)==0:
        desc_vec=np.zeros((1, 200))
    else:
        desc_vec = np.mean(word2vec_ls, axis=0).reshape(1, 200)
    # append the new document vector into the parent array
    description_vec=np.vstack([description_vec, desc_vec])

# %%
description_vec.shape
# Out:
# (4999, 200)

# %%
# RUN THIS CELL ONLY WHEN IMPLEMENTING VERSION 2

icd_vec_mean = np.mean(icd_vec, axis = 0)
desc_vec_new = np.empty((0,200),float)
for item in description_vec:
    item = np.subtract(item, icd_vec_mean)
    desc_vec_new = np.vstack([desc_vec_new, item])

desc_vec_new.shape
# Out:
# (4999, 200)

# %%
# write mt vector matrix to a csv file
dfDesV = pd.DataFrame(description_vec)
dfDesV.to_csv(path_or_buf = './data/DesV_v3.csv', index=False)
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0
# 12    0.098157  0.066485  0.191585    ...     0.114358  0.250043  0.234093
# 13   -0.061720 -0.123394  0.228815    ...     0.041853 -0.007572  0.104728
# 14   -0.182325 -0.021261  0.196731    ...     0.115286 -0.018309  0.247502
# 15   -0.089183 -0.116337  0.291718    ...     0.019334 -0.143369 -0.042488
# 16   -0.198665 -0.026278  0.161258    ...     0.058058  0.115633  0.091544
# 17   -0.102636 -0.011539  0.103273    ...     0.069132 -0.027344  0.051671
# 18   -0.073523  0.005051  0.169682    ...     0.128484  0.045374 -0.000688
# 19   -0.035957 -0.076355  0.107737    ...     0.050929  0.007203  0.054533
# 20   -0.049805 -0.012365  0.016820    ...     0.012574 -0.030593 -0.091693
# 21   -0.048798 -0.258441  0.291830    ...     0.096932  0.073577  0.161480
# 22   -0.038285 -0.032259  0.089737    ...     0.145764  0.071559 -0.152602
# 23    0.066881 -0.046994  0.083076    ...     0.217023 -0.121285 -0.087441
# 24   -0.210386 -0.195925  0.036659    ...     0.028196 -0.090336 -0.025575
# 25   -0.038285 -0.032259  0.089737    ...     0.145764  0.071559 -0.152602
# 26   -0.002457 -0.094092  0.209403    ...     0.122619 -0.083180  0.085823
# 27   -0.089823 -0.114485  0.047530    ...     0.014060  0.087423  0.162031
# 28    0.032383 -0.021120 -0.031126    ...     0.071602  0.006425 -0.165277
# 29    0.005691 -0.038640  0.045621    ...     0.080257  0.005719 -0.032648
# ...        ...       ...       ...    ...          ...       ...       ...
# 4969  0.021273 -0.135962  0.040735    ...    -0.023724 -0.003866  0.048646
# 4970  0.016561 -0.050994  0.139680    ...     0.056290  0.159374  0.118385
# 4971 -0.044863 -0.000332  0.001851    ...    -0.012819 -0.070514 -0.110152
# 4972 -0.040993 -0.043177  0.097781    ...     0.099318  0.083561 -0.023904
# 4973 -0.011205 -0.128828  0.216158    ...     0.091651 -0.106120  0.150443
# 4974 -0.054971 -0.066064  0.085478    ...     0.016606 -0.058926  0.009884
# 4975  0.052231 -0.072267  0.133471    ...     0.103491 -0.036411  0.029762
# 4976  0.120310  0.016732  0.089881    ...     0.018425 -0.026801  0.135063
# 4977  0.157014 -0.010548  0.161333    ...     0.212205 -0.041709  0.020213
# 4978 -0.002110 -0.102489  0.151338    ...     0.083933 -0.031651  0.044747
# 4979 -0.020718 -0.227873  0.222543    ...     0.019412 -0.025635  0.089989
# 4980  0.003269 -0.114309  0.234381    ...    -0.008615 -0.087137  0.099235
# 4981 -0.060305  0.022010  0.001936    ...     0.048538  0.212069  0.289864
# 4982  0.106759 -0.231655  0.425522    ...     0.015301 -0.124537  0.014511
# 4983 -0.232627  0.032461  0.222762    ...     0.123930  0.210846  0.239245
# 4984  0.066925  0.019152  0.136628    ...     0.105394  0.010279  0.039742
# 4985 -0.081600 -0.210110  0.265041    ...     0.117937 -0.090149  0.072828
# 4986 -0.069776 -0.017848  0.215897    ...     0.062501  0.153895  0.044841
# 4987 -0.165258 -0.070904  0.248686    ...     0.032236  0.096668  0.178185
# 4988 -0.142835  0.040974  0.377200    ...     0.259703  0.244138  0.242985
# 4989  0.003269 -0.114309  0.234381    ...    -0.008615 -0.087137  0.099235
# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
# construct the collection of all icd desc and 5000 mts

corpus = []

# extract icd desc
stop_words = set(stopwords.words('english'))
for i in range(20): 
    ite_name = i+1
    file = open("./data/icd%d.txt" %ite_name, "r", encoding='UTF-8')
    raw_data = file.read()
    file.close()
    corpus.append(raw_data)

# extract mt
for i in range(len(mt['description'])):
    corpus.append(mt['description'][i])

# %%
# generate the tf-idf weight matrix

# construct a count matrix and get the list of words
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(corpus)
listWord = vectorizer.get_feature_names()

# construct a tf-idf matrix
transformer = TfidfTransformer()
tfidf = transformer.fit_transform(X)

# convert the output to an array for better usage
arrWeight = tfidf.toarray()

# %%
# convert icd desc and medical transcription to vectors
icd_vec=np.empty((0, 200), float)

for i in range(20): 
    ite_name = i+1
    file = open("./data/icd%d.txt" %ite_name, "r")
    raw_data = file.read()
    file.close()

    stop_words = set(stopwords.words('english')) 
    word_tokens = word_tokenize(raw_data)
    
    #convert all words to lower case
    word_tokens = [w.lower() for w in word_tokens] 
    #remove words in stopwords list
    word_tokens = [w.lower() for w in word_tokens if w not in stop_words] 
    #only keep alphabetic terms
    word_tokens = [w.lower() for w in word_tokens if w.isalpha()] 
    
    token_pos=nltk.pos_tag(word_tokens)

    word2vec_ls=np.empty((0, 200), float)
    weight_ls = []
    
    for word, pos in token_pos:
        if (pos in ['NN', 'NNP', 'NNS', 'NNPS'] and word in listWord):
            try:
                indWord = listWord.index(word)
                word2vec_ls=np.vstack([word2vec_ls, model.word_vec(word)])
                weight_ls.append(arrWeight[i][indWord])
            except:
                pass

    if np.any(np.isnan(word2vec_ls)) or len(word2vec_ls)==0:
        desc_vec=np.zeros((1, 200))
    else:
        desc_vec = np.average(word2vec_ls, axis=0, weights=weight_ls, returned=False)
    icd_vec=np.vstack([icd_vec, desc_vec])

# %%
description_vec=np.empty((0, 200), float)

for i in range(len(mt["description"])):
    word2vec_ls=np.empty((0, 200), float)
    weight_ls = []
    mt_token_pos=nltk.pos_tag(nltk.word_tokenize(mt["description"][i]))
    
    #convert all words to lower case
    word_tokens = [w.lower() for w in word_tokens] 
    #remove words in stopwords list
    word_tokens = [w.lower() for w in word_tokens if w not in stop_words] 
    #only keep alphabetic terms
    word_tokens = [w.lower() for w in word_tokens if w.isalpha()] 
    
    # for each word in a case, convert t into vector using model
    # take the exception into consideration (i.e.: word is not in the model)
    for word, pos in mt_token_pos:
        if (pos in ['NN', 'NNP', 'NNS', 'NNPS'] and word in listWord):
            try:
                indWord = listWord.index(word)
                word2vec_ls=np.vstack([word2vec_ls, model.word_vec(word)])
                weight_ls.append(arrWeight[i+20][indWord])
            except:
                pass
    # if the case is empty, convert the document vector into zeros, otherwise calculate the average value of word vectors
    if np.any(np.isnan(word2vec_ls)) or len(word2vec_ls)==0:
        desc_vec=np.zeros((1, 200))
    else:
        desc_vec = np.average(word2vec_ls, axis=0, weights=weight_ls, returned=False)
    # append the new document vector into the parent array
    description_vec=np.vstack([description_vec, desc_vec])

# %%
# write sim matrix to a csv file
dfIcdV = pd.DataFrame(icd_vec)
dfIcdV.to_csv(path_or_buf = './data/IcdV_v4.csv', index=False)

# write mt vector matrix to a csv file
dfDesV = pd.DataFrame(description_vec)
dfDesV.to_csv(path_or_buf = './data/DesV_v4.csv', index=False)

# %% [markdown]
# ## 5 Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
sim = cosine_similarity(description_vec, icd_vec)

# %%
sim
# Out:
# array([[0.3553884 , 0.38406894, 0.36978634, ..., 0.43369216, 0.35759767,
#         0.31261114],
#        [0.07466101, 0.18418707, 0.05656946, ..., 0.13179793, 0.24739479,
#         0.09449073],
#        [0.07466101, 0.18418707, 0.05656946, ..., 0.13179793, 0.24739479,
#         0.09449073],
#        ...,
#        [0.36978281, 0.22404419, 0.33582207, ..., 0.39386017, 0.28608588,
#         0.28919567],
#        [0.36644213, 0.20221795, 0.23334095, ..., 0.41779517, 0.2854135 ,
#         0.28181405],
#        [0.55487984, 0.50869265, 0.46281272, ..., 0.5107827 , 0.35825746,
#         0.25132562]])

# %%
# calculate the mean, median value and maximum value as reference to determine a threshold 
print(np.median(sim))
print(np.mean(sim))
print(np.max(sim))
# Out:
# 0.2073973010080073
# 0.22690196166648854
# 0.9109624806359938

# %%
# construct a list of ICD titles
dictIcd = {
    0: 'Certain infectious and parasitic diseases',
    1: 'Neoplasms',
    2: 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism',
    3: 'Endocrine, nutritional and metabolic diseases',
    4: 'Mental and behavioural disorders',
    5: 'Diseases of the nervous system',
    6: 'Diseases of the eye and adnexa',
    7: 'Diseases of the ear and mastoid process',
    8: 'Diseases of the circulatory system',
    9: 'Diseases of the respiratory system',
    10:'Diseases of the digestive system',
    11:'Diseases of the skin and subcutaneous tissue',
    12:'Diseases of the musculoskeletal system and connective tissue',
    13:'Diseases of the genitourinary system',
    14:'Pregnancy, childbirth and the puerperium',
    15:'Certain conditions originating in the perinatal period',
    16:'Congenital malformations, deformations and chromosomal abnormalities',
    17:'Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified',
    18:'Injury, poisoning and certain other consequences of external causes',
    19:'External causes of morbidity and mortality',
    20:'Factors influencing health status and contact with health services',
    21:'Codes for special purposes'
}

# %%
icd_match = np.empty((0,1), )
icd_sim = np.empty((0,1),)
for i in range(len(sim)):
    index, =np.where(sim[i] == np.amax(sim[i]))
    simMax = np.amax(sim[i])
    if sim[i,index[0]] > 0.6:
        icd_match = np.vstack([icd_match, dictIcd[index[0]]])
        icd_sim = np.vstack([icd_sim, simMax])
    else: 
        icd_match = np.vstack([icd_match, 'No type matched'])
        icd_sim = np.vstack([icd_sim, simMax])

# %%
# print the data volume after filtering using the threshold
len(np.where(icd_match != "No type matched")[0])
# Out:
# 1030

# %%
icd_match
# Out:
# array([['Diseases of the skin and subcutaneous tissue'],
#        ['No type matched'],
#        ['No type matched'],
#        ...,
#        ['Diseases of the respiratory system'],
#        ['No type matched'],
#        ['Diseases of the respiratory system']], dtype='<U99')

# %%
from sklearn.utils import shuffle
dfMatch = pd.DataFrame(icd_match, columns = ['type'])
dfMatch['desc'] = mt['description']
dfMatch['sim'] = icd_sim

# %%
dfMatch
# Out:
#                                                    type  \
# 0                                       No type matched
# 1                                       No type matched
# 2                                       No type matched
# 3                                       No type matched
# 4                                       No type matched
# 5                                       No type matched
# 6                                       No type matched
# 7                                       No type matched
# 8                                       No type matched
# 9                                       No type matched
# 10                                      No type matched
# 11                   Diseases of the circulatory system
# 12                                      No type matched
# 13                                      No type matched
# 14                                      No type matched
# 15                                      No type matched
# 16                                      No type matched
# 17                                      No type matched
# 18                                      No type matched
# 19                                      No type matched
# 20                                      No type matched
# 21                                      No type matched
# 22                                      No type matched
# 23                                      No type matched
# 24                                      No type matched
# 25                                      No type matched
# 26                                      No type matched
# 27                                      No type matched
# 28                                      No type matched
# 29                                      No type matched
# ...                                                 ...
# 4969                 Diseases of the circulatory system
# 4970                                    No type matched
# 4971                                    No type matched
# 4972                                    No type matched
# 4973                                    No type matched
# 4974                                    No type matched
# 4975                                    No type matched
# 4976                                    No type matched
# 4977                                    No type matched
# 4978                                    No type matched
# 4979                                    No type matched
# 4980                                    No type matched
# 4981                                    No type matched
# 4982                                    No type matched
# 4983                                    No type matched
# 4984                                    No type matched
# 4985                                    No type matched
# 4986                                    No type matched
# 4987  Injury, poisoning and certain other consequenc...
# 4988  Injury, poisoning and certain other consequenc...
# 4989                                    No type matched
# 4990                                    No type matched
# 4991                                    No type matched
# 4992  Injury, poisoning and certain other consequenc...
# 4993       Diseases of the skin and subcutaneous tissue
# 4994                                    No type matched
# 4995                                    No type matched
# 4996                                    No type matched
# 4997                                    No type matched
# 4998                                    No type matched
#
#                                                    desc       sim
# 0      A 23-year-old white female presents with comp...  0.553067
# 1              Consult for laparoscopic gastric bypass.  0.419301
# 2              Consult for laparoscopic gastric bypass.  0.419301
# 3                                2-D M-Mode. Doppler.    0.000000
# 4                                    2-D Echocardiogram  0.000000
# 5      Morbid obesity.  Laparoscopic antecolic anteg...  0.425851
# 6      Liposuction of the supraumbilical abdomen, re...  0.528354
# 7                                    2-D Echocardiogram  0.000000
# 8      Suction-assisted lipectomy - lipodystrophy of...  0.499652
# 9                            Echocardiogram and Doppler  0.000000
# 10     Morbid obesity.  Laparoscopic Roux-en-Y gastr...  0.512841
# 11     Normal left ventricle, moderate biatrial enla...  0.735156
# 12               Cerebral Angiogram - moyamoya disease.  0.514376
# 13     Patient presented to the bariatric surgery se...  0.435067
# 14      Surgical removal of completely bony impacted...  0.246351
# 15     Preoperative visit for weight management with...  0.530445
# 16     Neck exploration; tracheostomy; urgent flexib...  0.393313
# 17              Patient status post lap band placement.  0.440735
# 18     Fertile male with completed family.  Elective...  0.471310
# 19     The patient is a 17-year-old female, who pres...  0.318563
# 20     Whole body radionuclide bone scan due to pros...  0.440506
# 21     Patient discharged after laparoscopic Roux-en...  0.459951
# 22                                     Normal vasectomy  0.435209
# 23     Voluntary sterility.  Bilateral vasectomy.  T...  0.206333
# 24     Blood in urine - Transitional cell cancer of ...  0.385375
# 25                                     Normal vasectomy  0.435209
# 26     Hispanic male patient was admitted because of...  0.540388
# 27     Umbilical hernia repair template.  The umbili...  0.457774
# 28     Vasectomy 10 years ago, failed.  Azoospermic....  0.242273
# 29     Desire for sterility.  Vasectomy.  The vas wa...  0.242287
# ...                                                 ...       ...
# 4969   Left heart catheterization, bilateral selecti...  0.762033
# 4970   Lower extremity angiogram, superficial femora...  0.584364
# 4971                           A sample note on Angina.  0.195578
# 4972   Adenosine with nuclear scan as the patient un...  0.250034
# 4973   Patient presents with a chief complaint of ch...  0.473210
# 4974   Patient had a recurrent left arm pain after h...  0.459065
# 4975   Patient had a markedly abnormal stress test w...  0.434777
# 4976   Abnormal echocardiogram findings and followup...  0.541377
# 4977   Gentleman with long-standing morbid obesity, ...  0.401949
# 4978   Preop evaluation regarding gastric bypass sur...  0.493223
# 4979   Patient scheduled for laparoscopic gastric by...  0.419301
# 4980   Evaluation for elective surgical weight loss ...  0.393587
# 4981   The patient died of a pulmonary embolism, the...  0.561373
# 4982                  Evaluation for bariatric surgery.  0.384210
# 4983   Autopsy - Homicide - evidence of exsanguinati...  0.543937
# 4984   Patient suffered from morbid obesity for many...  0.487027
# 4985   Patient presented to the Bariatric Surgery Se...  0.379722
# 4986   Autopsy of a white female who died of acute c...  0.400944
# 4987   Multiple sharp force injuries, involving ches...  0.682216
# 4988    Autopsy - Homicide - Blunt force cranial trauma  0.675850
# 4989   Evaluation for elective surgical weight loss ...  0.393587
# 4990             Cause of death - Anoxic Encephalopathy  0.434140
# 4991   Autopsy - Asphyxia due to ligature strangulat...  0.524329
# 4992   Autopsy - Ligature strangulation and cranioce...  0.610859
# 4993   Chronic glossitis, xerostomia, probable envir...  0.692001
# 4994   Patient having severe sinusitis about two to ...  0.573607
# 4995   This is a 14-month-old baby boy Caucasian who...  0.593572
# 4996   A female for a complete physical and follow u...  0.592807
# 4997   Mother states he has been wheezing and coughing.  0.293771
# 4998   Acute allergic reaction, etiology uncertain, ...  0.412536
#
# [4999 rows x 3 columns]

# %%
dfMatchShfl = shuffle(dfMatch[dfMatch['type']!="No type matched"])

# %%
print(dfMatchShfl[0:10])
# Out:
#                                                    type  \
# 1245  Diseases of the musculoskeletal system and con...
# 398                  Diseases of the circulatory system
# 3922                   Diseases of the digestive system
# 4860                 Diseases of the circulatory system
# 4148  Injury, poisoning and certain other consequenc...
# 4099            Diseases of the ear and mastoid process
# 1009                   Diseases of the digestive system
# 4904                 Diseases of the circulatory system
# 2570  Certain conditions originating in the perinata...
# 1350               Diseases of the genitourinary system
#
#                                                    desc       sim
# 1245   Anterior cervical discectomy fusion C3-C4 and...  0.648441
# 398    Pulmonary valve stenosis, supple pulmonic nar...  0.797496
# 3922   Acute gastroenteritis, resolved.  Gastrointes...  0.774666
# 4860   A 10-1/2-year-old born with asplenia syndrome...  0.703149
# 4148   Records review.  The patient developed shooti...  0.662990
# 4099   The patient's main complaint is vertigo. The ...  0.665431
# 1009   Colon cancer screening and family history of ...  0.680345
# 4904   The patient has a previous history of aortic ...  0.768885
# 2570   Primary low transverse cesarean section via P...  0.654025
# 1350   Obesity hypoventilation syndrome.  A 61-year-...  0.639374

# %%
# write the randomly selected ten matches for accuracy score calculation
dfMatchShfl[0:10].to_csv(path_or_buf = './data/accuracy_v4.1.0.csv', index = False)

# %% [markdown]
# ## 6 Finalization

# %%
# write sim matrix to a csv file
dfSim = pd.DataFrame(sim)
dfSim['desc'] = mt["description"]
dfSim.to_csv(path_or_buf = './data/sim_v4.csv', index=False)

# %%
# write mt-type match to a csv file
dfMatch.to_csv(path_or_buf = './data/match_v4.1.csv', index = False)
